# %%
### Read CSV

# %%
import pandas as pd
import math
import numpy as np

# %%
sharp_data = pd.read_csv("INGCSharpService_client_info.csv")

# %%
removing_ingc = sharp_data[sharp_data!="ingc-team@amazon.com"]

# %%
without_nan_sharp = removing_ingc[pd.notnull(removing_ingc['Email'])]

# %%
without_nan_sharp.to_csv("sharp.csv")

# %%
final_sharp
# Out:
#     Client Name Service Name                 Email Category Type Item  \
# 2           NaN          NaN  ingc-team@amazon.com      NaN  NaN  NaN
# 5           NaN          NaN                   NaN      NaN  NaN  NaN
# 12          NaN          NaN  ingc-team@amazon.com      NaN  NaN  NaN
# 13          NaN          NaN                   NaN      NaN  NaN  NaN
# 15          NaN          NaN                   NaN      NaN  NaN  NaN
# 17          NaN          NaN  ingc-team@amazon.com      NaN  NaN  NaN
# 23          NaN          NaN                   NaN      NaN  NaN  NaN
# 24          NaN          NaN                   NaN      NaN  NaN  NaN
# 25          NaN          NaN                   NaN      NaN  NaN  NaN
# 26          NaN          NaN                   NaN      NaN  NaN  NaN
# 27          NaN          NaN                   NaN      NaN  NaN  NaN
# 29          NaN          NaN                   NaN      NaN  NaN  NaN
# ...
